# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnam95/my/blob/main/YES24API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup
import re
import numpy as np

# %%
bookID = '176787'

# %%
url = f'http://www.yes24.com/Product/communityModules/GoodsReviewList/{bookID}?Sort=1&PageNumber=1&Type=ALL'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
tmp = soup.find(string=re.compile('reviewCountText'))
tmp = str(tmp)
cnt = re.findall('(?<= reviewCountText = \')\d*(?=\')', tmp)
cnt = int(cnt[0])

nPage = int(np.ceil(cnt/5))

# %%
data = {'title': [],
        'score': [],
        'ID': [],
        'date': [],
        'text': []}

df = pd.DataFrame(data)

# %%
for n in range(nPage):
  PageNumber = n + 1
  url = f'http://www.yes24.com/Product/communityModules/GoodsReviewList/{bookID}?Sort=1&PageNumber={PageNumber}&Type=ALL'
  response = requests.get(url)
  
  soup = BeautifulSoup(response.content, 'html.parser')
  title = soup.select('span.txt')
  review_origin = soup.select('div.reviewInfoBot.origin > div.review_cont')

  for i, r in enumerate(zip(title, review_origin)):
    title, text = [r[0].get_text(), r[1].get_text()]    
    row = [title, '', '', '', text]
    df.loc[i, :] = row

# %%
df

# %%
review_origin

# %%
<span class="txt">[철학] 당신은 선악과를 먹었습니까_데미안</span>
<span class="rating rating_5 bgGD">평점5점</span>
<span class="rating rating_5 bgGD">평점5점</span>
<a class="lnk_id" href="javascript:void(0)" onclick="makeBlogMnu(this, '476270', '0', event);">k*******4</a>
<em class="txt_date">2022-11-02</em>

# %%
soup
# Out:
# <div class="infoSetCont_wrap reviewRow_cont tp_tab yesComLoadingArea" id="infoset_reviewContentList">
# <div class="review_sort sortTop">
# <div class="review_sortLft"><div class="yesUI_pagenS"><a class="bgYUI first dim" href="javascript:void(0);">처음</a>
# <a class="bgYUI prev dim" href="javascript:void(0);">이전</a>
# <strong class="num">1</strong>
# <a class="num" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=2&amp;Type=ALL" onclick="urlClickForReview(this);return false;">2</a>
# <a class="num" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=3&amp;Type=ALL" onclick="urlClickForReview(this);return false;">3</a>
# <a class="num" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=4&amp;Type=ALL" onclick="urlClickForReview(this);return false;">4</a>
# ...
