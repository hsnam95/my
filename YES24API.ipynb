# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnam95/my/blob/main/YES24API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup
import re
import numpy as np

# %%
bookID = '176787'

# %%
url = f'http://www.yes24.com/Product/communityModules/GoodsReviewList/{bookID}?Sort=1&PageNumber=1&Type=ALL'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
tmp = soup.find(string=re.compile('reviewCountText'))
# text = tmp.get_text()
tmp = str(tmp)
cnt = re.findall('(?<= reviewCountText = \')\d*(?=\')', tmp)
cnt = int(cnt[0])

nPage = int(np.ceil(cnt/5))

# %%
rall = []

for n in range(nPage):
  PageNumber = n + 1
  url = f'http://www.yes24.com/Product/communityModules/GoodsReviewList/{bookID}?Sort=1&PageNumber={PageNumber}&Type=ALL'
  response = requests.get(url)
  
  soup = BeautifulSoup(response.content, 'html.parser')
  review_origin = soup.select('div.reviewInfoBot.origin > div.review_cont')

  for r in review_origin:
    cont = r.select('p')
    if cont:
      ps = [p.get_text() for p in cont]
      pall = ''.join(ps)
    else:
      pall = r.get_text()
    rall.append(pall)

# %%
soup
# Out:
# <div class="infoSetCont_wrap reviewRow_cont tp_tab yesComLoadingArea" id="infoset_reviewContentList">
# <div class="review_sort sortTop">
# <div class="review_sortLft"><div class="yesUI_pagenS"><a class="bgYUI first" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=1&amp;Type=ALL" onclick="urlClickForReview(this);return false;">처음</a>
# <a class="bgYUI prev" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=60&amp;Type=ALL" onclick="urlClickForReview(this);return false;">이전</a>
# <a class="num" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=61&amp;Type=ALL" onclick="urlClickForReview(this);return false;">61</a>
# <a class="num" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=62&amp;Type=ALL" onclick="urlClickForReview(this);return false;">62</a>
# <a class="num" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=63&amp;Type=ALL" onclick="urlClickForReview(this);return false;">63</a>
# <strong class="num">64</strong>
# <a class="bgYUI next dim" href="javascript:void(0);">다음</a>
# <a class="bgYUI end dim" href="javascript:void(0);">끝</a></div></div></div></div>
# <script>function urlClickForReview(obj) {    var url = $(obj).attr('href');    var current_sorting_id = $(obj).attr('id');    var gdreviewTab = new Object();    var sort_tp = getSortTp(current_sorting_id);    if (typeof (current_sorting_id) != 'undefined') {        setCookie('LAST_REVIEW_TAB', sort_tp, 30);    }    if ($('#infoset_reviewTab').hasClass('yesTab_nor')) {        gdreviewTab = $('#infoset_reviewTab');    } else {        gdreviewTab = $('#score_reivew_result');    }    $('html, body').stop().animate({ scrollTop: gdreviewTab.offset().top - 101 }, 300, 'easeInOutQuart');    loadingShow('infoset_reviewContentList');    loadItem('infoset_reviewContentList', url);}</script>
# <div class="review_sortRgt" id="review_sort_area">
# <label><input id="chkOrderReviewForReview" onchange="wiseLog('Pcode','012_004_002');fnDojungAfterBuyForReview(this,1);" type="checkbox"/> 구매리뷰</label>
# <a class="on" href="/Product/communityModules/GoodsReviewList/176787?Type=ALL&amp;Sort=1&amp;PageNumber=1" id="review_recent" onclick="wiseLog('Pcode','012_004_003');urlClickForReview(this);return false;">최근순</a>
# <em class="divi">|</em>
# <a class="" href="/Product/communityModules/GoodsReviewList/176787?Type=ALL&amp;Sort=2&amp;PageNumber=1" id="review_recommend" onclick="wiseLog('Pcode','012_004_004');urlClickForReview(this);return false;">추천순</a>
# <em class="divi">|</em>
# <a class="" href="/Product/communityModules/GoodsReviewList/176787?Type=ALL&amp;Sort=3&amp;PageNumber=1" id="review_star_score" onclick="wiseLog('Pcode','012_004_005');urlClickForReview(this);return false;">별점순</a>
# </div>
#
# <script>
# </script>
# <!-- ############################## 리뷰 하나 반복 시작 ############################## -->
# <div class="reviewInfoGrp lnkExtend">
# <div class="reviewInfoTop">
# <span class="review_tit">
# <span class="txt">젊은이들에게...</span>
# </span>
# <div class="review_etc">
# <span class="review_rating">
#                     내용 <span class="rating rating_5 bgGD">평점5점</span>
#
#                     편집/디자인 <span class="rating rating_5 bgGD">평점5점</span>
# </span>
# <em class="divi">|</em>
# <em class="txt_id">
# <a class="lnk_id" href="javascript:void(0)" onclick="makeBlogMnu(this, '648545', '0', event);">r********7</a>
# </em>
# <em class="divi">|</em>
# <em class="txt_date">2002-03-18</em>
# </div>
# </div>
# <div class="reviewInfoBot crop">
# <a class="review_cropLnk" href="javascript:void(0);" onclick="toggleInfoSubSet(this);">
# <div class="review_cont">
#
#                     이 책이 나올 당시에도 그랬다지? 그 때에도 많은 젊은이들에게 이 책은 많은 영향을 미쳤다지? 그 때만큼은 아닌 것 같지만 지금까지도 이 책은 꾸준히 젊은이들에게 영향을 미치고 있는 것으로 보인다. 여러가지 부분에서 싱클레어와 비슷하던 열 세살의 난 데미안을 만나면서 아프락사스를 꿈꾸었었다.
# 중학교에 처음 들어가 이 책을 만나고 난 뒤 얼마나 자주...
#                     <span class="review_more">더보기<em class="bgYUI ico_arr"></em></span>
# </div>
# </a>
# </div>
# <div class="reviewInfoBot origin">
# <div class="review_lnk"><p>원문주소 : <a href="http://blog.yes24.com/document/209765" target="_blank">http://blog.yes24.com/document/209765</a></p></div>
# <div class="review_cont">
#                 이 책이 나올 당시에도 그랬다지? 그 때에도 많은 젊은이들에게 이 책은 많은 영향을 미쳤다지? 그 때만큼은 아닌 것 같지만 지금까지도 이 책은 꾸준히 젊은이들에게 영향을 미치고 있는 것으로 보인다. 여러가지 부분에서 싱클레어와 비슷하던 열 세살의 난 데미안을 만나면서 아프락사스를 꿈꾸었었다.
# 중학교에 처음 들어가 이 책을 만나고 난 뒤 얼마나 자주 읽었는지... 그리고 헤세의 책을 얼마나 찾아다녔는지... 결국 현재에 남은 건 기억뿐이다. 내게 어떤 작품이 안 그러하겠느냐마는... 하지만 그 기억이 현재에는 보석함 속에 넣고 잘 사용하지는 않지만 가끔 꺼내어보는 나의 재산이 되어있다.
# 젊은이들에게는 이 책을 추천하고 싶지는 않다. 오히려 멀리하라고 이르고 싶다. 왜냐하면 데미안을 만나면 그대로 빠져버릴테니까... 대신 어쩔 수 없이 그를 만났다면 제대로 한 번 빠져보라고는 추천하고 싶다. 쓰다보니 책의 내용은 언급하지 않았는데, 쓸 말이 없다. 이 책에서 중요한 건 데미안, 그렇게 불리우는 사람, 그 자신 이다.
#             </div>
# </div>
# <div class="reviewInfoLike">
# <span class="txt_sympathy">2명이 이 리뷰를 추천합니다.</span>
# <a class="btnC s_size " href="javascript:void(0);" onclick="RecommendReviewForProduct(209765,648545,64,'ALL',0,1,176787,0,'infoset_reviewContentList', this);"><span class="bWrap"><em class="bgGD ico_sympathy">공감</em><em class="yes_b txt">2</em></span></a>
# <a class="btnC s_size" href="http://blog.yes24.com/document/209765" target="_blank"><span class="bWrap"><em class="txt">댓글 <strong class="yes_b">0</strong></em><em class="bgYUI ico_goS"></em></span></a>
# <a class="downSize" href="javascript:void(0);" onclick="toggleInfoSubSet(this);">접어보기<em class="bgYUI ico_arr"></em></a>
# </div>
# </div>
# <div class="reviewInfoGrp lnkExtend">
# <div class="reviewInfoTop">
# <span class="review_tit">
# <span class="txt">이해하기 좀 난해하지만...</span>
# </span>
# <div class="review_etc">
# <span class="review_rating">
#                     내용 <span class="rating rating_4 bgGD">평점4점</span>
#
#                     편집/디자인 <span class="rating rating_4 bgGD">평점4점</span>
# </span>
# <em class="divi">|</em>
# <em class="txt_id">
# <a class="lnk_id" href="javascript:void(0)" onclick="makeBlogMnu(this, '1226388', '0', event);">s*******2</a>
# </em>
# <em class="divi">|</em>
# <em class="txt_date">2002-08-31</em>
# </div>
# </div>
# <div class="reviewInfoBot crop">
# <a class="review_cropLnk" href="javascript:void(0);" onclick="toggleInfoSubSet(this);">
# <div class="review_cont">
#
#                     책을 좋아하는 아니 책과는 좀 거리가 있는 사람이라도 아마 '데미안' 을 모르는 사람은 거의 없을 듯하다. 그만큼 유명한 작품이거니와 온국민의 필독서로 인정되고 있는 작품이기 때문이다. 문학이 전공도 아니고 문학적 소양도 없는 나에게 이 책은 좀 어려웠다. 글을 쓰고 있는 이 순간에도 '어떤 것을 써야하나?' 라는 생각에 조금은 두렵다.
#
# 우선 이 책은...
#                     <span class="review_more">더보기<em class="bgYUI ico_arr"></em></span>
# </div>
# </a>
# </div>
# <div class="reviewInfoBot origin">
# <div class="review_lnk"><p>원문주소 : <a href="http://blog.yes24.com/document/198183" target="_blank">http://blog.yes24.com/document/198183</a></p></div>
# <div class="review_cont">
#                 책을 좋아하는 아니 책과는 좀 거리가 있는 사람이라도 아마 '데미안' 을 모르는 사람은 거의 없을 듯하다. 그만큼 유명한 작품이거니와 온국민의 필독서로 인정되고 있는 작품이기 때문이다. 문학이 전공도 아니고 문학적 소양도 없는 나에게 이 책은 좀 어려웠다. 글을 쓰고 있는 이 순간에도 '어떤 것을 써야하나?' 라는 생각에 조금은 두렵다.
#
# 우선 이 책은 싱클레어의 성장기를 다루고 있으며 이 시기에 가장 큰 영향을 싱클레어에게 미친 사람이 막스 베버이다. 자아의 분열상을 느끼며 삶의 고뇌에 빠져 있을 때마다 데미안은 싱클에어의 충고자, 조언자, 상담자로서 친구가 되어 준다. 데미안이 옆에서 지켜 준 덕분에 싱클레어는 마침내 생의 허무를 극복하고 자아의 확립을 이룬다는 이야기이다. 이야기 구조는 이해하기 그리 어렵지 않지만 이에 내재된 뜻을 파악하기에는 어려웠다. 그래서 남들처럼 '어떤 커다란 깨달음을 얻거나 지금까지 읽어본 것중에 가장 훌륭한 작품이다' 라는 말은 차마 못하겠다. 하지만 이 구절은 좀 의미심장하게 다가왔다.
#
# &lt;새는 알에서 깨어난다. 알은 세계이다. 태어나려는 자는 하나의 세계를 깨뜨려야 한다. 신의 이름은 압락시스.&gt; 정확하게 어떤 의미라고 말할 수 없는 이 책...느낌은 오지만 말로 표현하기 어려운 이상한 기분...바로 이런 것이 고전인가?
#             </div>
# </div>
# <div class="reviewInfoLike">
# <span class="txt_sympathy">2명이 이 리뷰를 추천합니다.</span>
# <a class="btnC s_size " href="javascript:void(0);" onclick="RecommendReviewForProduct(198183,1226388,64,'ALL',0,1,176787,0,'infoset_reviewContentList', this);"><span class="bWrap"><em class="bgGD ico_sympathy">공감</em><em class="yes_b txt">2</em></span></a>
# <a class="btnC s_size" href="http://blog.yes24.com/document/198183" target="_blank"><span class="bWrap"><em class="txt">댓글 <strong class="yes_b">0</strong></em><em class="bgYUI ico_goS"></em></span></a>
# <a class="downSize" href="javascript:void(0);" onclick="toggleInfoSubSet(this);">접어보기<em class="bgYUI ico_arr"></em></a>
# </div>
# </div>
# <div class="reviewInfoGrp lnkExtend">
# <div class="reviewInfoTop">
# <span class="review_tit">
# <span class="txt">성장소설.</span>
# </span>
# <div class="review_etc">
# <span class="review_rating">
#                     내용 <span class="rating rating_3 bgGD">평점3점</span>
#
#                     편집/디자인 <span class="rating rating_4 bgGD">평점4점</span>
# </span>
# <em class="divi">|</em>
# <em class="txt_id">
# <a class="lnk_id" href="javascript:void(0)" onclick="makeBlogMnu(this, '389345', '0', event);">j******e</a>
# </em>
# <em class="divi">|</em>
# <em class="txt_date">2002-04-23</em>
# </div>
# </div>
# <div class="reviewInfoBot crop">
# <a class="review_cropLnk" href="javascript:void(0);" onclick="toggleInfoSubSet(this);">
# <div class="review_cont">
#
#                     예전에 글씨가 자그마했던 책을 기억한다. 하지만 다시금 시간을 멈추고(?) 되돌아가 읽기를 청하게 되는 사연은 그냥이었다. 햄릿을 대본으로 읽고자 하다가 한꺼번에 몇권을 구입하게 되었다. 이렇게 읽게 된 사연은 우연.
#
# 막스 데미안, 싱클레어, 에바 부인 그리고 크로머. 솔직히 예전에 읽었던 기억속에는 내용자체가 어렵고, 비유와 은유 상징에 적응하지...
#                     <span class="review_more">더보기<em class="bgYUI ico_arr"></em></span>
# </div>
# </a>
# </div>
# <div class="reviewInfoBot origin">
# <div class="review_lnk"><p>원문주소 : <a href="http://blog.yes24.com/document/182935" target="_blank">http://blog.yes24.com/document/182935</a></p></div>
# <div class="review_cont">
#                 예전에 글씨가 자그마했던 책을 기억한다. 하지만 다시금 시간을 멈추고(?) 되돌아가 읽기를 청하게 되는 사연은 그냥이었다. 햄릿을 대본으로 읽고자 하다가 한꺼번에 몇권을 구입하게 되었다. 이렇게 읽게 된 사연은 우연.
#
# 막스 데미안, 싱클레어, 에바 부인 그리고 크로머. 솔직히 예전에 읽었던 기억속에는 내용자체가 어렵고, 비유와 은유 상징에 적응하지 못하면서도 페이지를 모두 넘겼다는 것에 위로했었지만, 지하철안에서 서서 시간때우기로 읽더라도 그리 어렵지 않았다.
#
# 자신의 문제가 고통스럽지 않아서가 아니라 알을 깨뜨리고 나온 그다음의, 그무엇에도 흥미롭지 않은 바라보기가 생활화 되어서 일지도 모른다고 생각했다. 하지만, 읽는 도중의 몇 문장은 여러 생각을 일깨웠으며, 나중엔 이상하게 매트릭스와 타크시티란 영화를 떠올리게 했다.
# 자아를 찾아가는 길에 대한 서술은 어쩌면 모두가 베끼기 이며, 그것을 이룩해 나가는 것은 본인임을 알기에, 그리고 기독교시각을 벗어나지 못하는 유럽문화의 속좁음에 대해서 배타적인 생각이 생겨서 인지...그렇게...하지만 위의 영화들 처럼 자신이 존재하고 있는 공간에 대한 해답찾기는 계속 생각하고 이루어져 나가는 것이 아닐까 생각되었다.
#
# 이렇게 성장소설인 데미안은 예전의 지적열등감을 조금이나마 치료하게되어서 좋았고, 번역자의 해제 또한 많이 유익했음을 알려주고 싶다.
#             </div>
# </div>
# <div class="reviewInfoLike">
# <span class="txt_sympathy">2명이 이 리뷰를 추천합니다.</span>
# <a class="btnC s_size " href="javascript:void(0);" onclick="RecommendReviewForProduct(182935,389345,64,'ALL',0,1,176787,0,'infoset_reviewContentList', this);"><span class="bWrap"><em class="bgGD ico_sympathy">공감</em><em class="yes_b txt">2</em></span></a>
# <a class="btnC s_size" href="http://blog.yes24.com/document/182935" target="_blank"><span class="bWrap"><em class="txt">댓글 <strong class="yes_b">0</strong></em><em class="bgYUI ico_goS"></em></span></a>
# <a class="downSize" href="javascript:void(0);" onclick="toggleInfoSubSet(this);">접어보기<em class="bgYUI ico_arr"></em></a>
# </div>
# </div>
# <div class="reviewInfoGrp lnkExtend">
# <div class="reviewInfoTop">
# <span class="review_tit">
# <span class="txt">자기 운명을 개척하고 자신을 찾기 위한 유럽문화비판</span>
# </span>
# <div class="review_etc">
# <span class="review_rating">
#                     내용 <span class="rating rating_4 bgGD">평점4점</span>
#
#                     편집/디자인 <span class="rating rating_4 bgGD">평점4점</span>
# </span>
# <em class="divi">|</em>
# <em class="txt_id">
# <a class="lnk_id" href="javascript:void(0)" onclick="makeBlogMnu(this, '834214', '0', event);"></a>
# </em>
# <em class="divi">|</em>
# <em class="txt_date">2001-04-16</em>
# </div>
# </div>
# <div class="reviewInfoBot crop">
# <a class="review_cropLnk" href="javascript:void(0);" onclick="toggleInfoSubSet(this);">
# <div class="review_cont">
#
#                     주인공 에밀 싱클레어는 내부에 두 개의 상반되는 세계를 가지고 그 대립 때문에 괴로워한다. 그것은 선과 악의 세계이다. 신앙심이 깊고 청결하며 예의 바른 부모로부터 영향받은 선의 세계와 하녀·장인들의 입을 통해 듣는 부랑자·주정뱅이·강도 등의 악의 세계가 자기의 내면에서 대립되고 있는 것을 느낀다.
#
# 내면에 상반되는 두 개의 혼을 가지고 있는 싱클레...
#                     <span class="review_more">더보기<em class="bgYUI ico_arr"></em></span>
# </div>
# </a>
# </div>
# <div class="reviewInfoBot origin">
# <div class="review_lnk"><p>원문주소 : <a href="http://blog.yes24.com/document/130940" target="_blank">http://blog.yes24.com/document/130940</a></p></div>
# <div class="review_cont">
#                 주인공 에밀 싱클레어는 내부에 두 개의 상반되는 세계를 가지고 그 대립 때문에 괴로워한다. 그것은 선과 악의 세계이다. 신앙심이 깊고 청결하며 예의 바른 부모로부터 영향받은 선의 세계와 하녀·장인들의 입을 통해 듣는 부랑자·주정뱅이·강도 등의 악의 세계가 자기의 내면에서 대립되고 있는 것을 느낀다.
#
# 내면에 상반되는 두 개의 혼을 가지고 있는 싱클레어는 위태로운 방황을 계속하지만, 데미안으로부터 '새는 알을 깨고 나온다. 알은 새의 세계이다. 태어나려는 자는 하나의 세계를 파괴하지 않으면 안 된다.'라는 메시지를 받고 자기 인식의 눈을 뜨게 된다. 내면에서 울려 퍼지는 운명의 목소리에 눈을 뜨게 된 것이다. 싱클레어는 자기 운명을 개척하고 자기 발견의 길을 걷기 위해 기성의 모든 것, 혼을 잃은 유럽의 문화를 철저하게 비판해야만 했다.
#
# 이 소설은 세계 제1차 대전이 끝난 후에 정신적인 폐허 속에서 헤매던 젊은이들에게 깊은 감동을 주었다. 특히 싱클레어의 인식의 과정을 통해 물질 문명만을 추구하다가 정신의 공허화를 초래한 유럽의 현실을 비판하고 있으며, 인간 자신의 내면에 귀를 기울일 것을 강조하고 있다. <br/><br/>[인상깊은구절]<br/>"우리는 고대의 그 교파의 신비적인 단체의 논법을 합리주의적인 관찰의 입장에서 생각하듯이 그렇게 소박하게 상상해서는 안 된다. 우리들이 가진 과학과 같은 것은 고대에는 전혀 알지 못했던 것이다. 그 대신 대단히 고도로 발전한 철학적 신비적인 진리에 대한 연구가 성행했다. 거기서부터 부분적으로는 분명히 사기와 범죄 행위로 나가기까지 한 마술과 유희가 발생했다. 그러나 그 마술 역시 고귀한 내력과 깊은 사상을 지니고 있었다.
#
#  내가 앞에서 예를 든 아프락사스의 설도 그렇다. 이 이름은 희랍의 주문과 관계가 있다고 말해지고 있는데, 오늘날에도 대개는 야만 민족이 가지고 있는 어떤 악마의 이름이라고 왕왕 생각되고 있다. 그러나 아프락사스는 훨씬 더 많은 것을 의미하고 있는 것으로 안다. 우리는 이 이름을 대략 신적인 것과 악마적인 것을 결합시키는 상징적 관계를 지닌 일종의 신이라고 생각할 수 있을 것이다."
#             </div>
# </div>
# <div class="reviewInfoLike">
# <span class="txt_sympathy">7명이 이 리뷰를 추천합니다.</span>
# <a class="btnC s_size " href="javascript:void(0);" onclick="RecommendReviewForProduct(130940,834214,64,'ALL',0,1,176787,0,'infoset_reviewContentList', this);"><span class="bWrap"><em class="bgGD ico_sympathy">공감</em><em class="yes_b txt">7</em></span></a>
# <a class="btnC s_size" href="http://blog.yes24.com/document/130940" target="_blank"><span class="bWrap"><em class="txt">댓글 <strong class="yes_b">1</strong></em><em class="bgYUI ico_goS"></em></span></a>
# <a class="downSize" href="javascript:void(0);" onclick="toggleInfoSubSet(this);">접어보기<em class="bgYUI ico_arr"></em></a>
# </div>
# </div>
# <div class="reviewInfoGrp lnkExtend">
# <div class="reviewInfoTop">
# <span class="review_tit">
# <span class="txt">데미안! 데미안! 나의 데미안아...</span>
# </span>
# <div class="review_etc">
# <span class="review_rating">
#                     내용 <span class="rating rating_5 bgGD">평점5점</span>
#
#                     편집/디자인 <span class="rating rating_4 bgGD">평점4점</span>
# </span>
# <em class="divi">|</em>
# <em class="txt_id">
# <a class="lnk_id" href="javascript:void(0)" onclick="makeBlogMnu(this, '1169361', '0', event);">r*****a</a>
# </em>
# <em class="divi">|</em>
# <em class="txt_date">2002-08-01</em>
# </div>
# </div>
# <div class="reviewInfoBot crop">
# <a class="review_cropLnk" href="javascript:void(0);" onclick="toggleInfoSubSet(this);">
# <div class="review_cont">
#
#                     나의 데미안과 에바부인은 어디에 있을까....! 내가 돌아 돌아 오게된 길...그러나 결코 찾을 수 없던 길..어쩌면 절실히 그 당시 나에게 필요한 책이었을 텐데..그렇다면 아직도 이렇게 헤메이진 않을 것 같다. 루이제 린저가 서두를 던져 놓았다면, 헤르만 헤세는 수행의 길을 보여주었다.
#
# 아직도 멀기만 하구나...! 난 언제쯤이면 데미안이 될 수 있으며...언...
#                     <span class="review_more">더보기<em class="bgYUI ico_arr"></em></span>
# </div>
# </a>
# </div>
# <div class="reviewInfoBot origin">
# <div class="review_lnk"><p>원문주소 : <a href="http://blog.yes24.com/document/129392" target="_blank">http://blog.yes24.com/document/129392</a></p></div>
# <div class="review_cont">
#                 나의 데미안과 에바부인은 어디에 있을까....! 내가 돌아 돌아 오게된 길...그러나 결코 찾을 수 없던 길..어쩌면 절실히 그 당시 나에게 필요한 책이었을 텐데..그렇다면 아직도 이렇게 헤메이진 않을 것 같다. 루이제 린저가 서두를 던져 놓았다면, 헤르만 헤세는 수행의 길을 보여주었다.
#
# 아직도 멀기만 하구나...! 난 언제쯤이면 데미안이 될 수 있으며...언제쯤 에바 부인을 만날 것인가...! 싱클레어 처럼 그토록 갈망하지도 않았던 것을....
#
# 이책은 이제 갓 사회 초년생이 되는 이나, 아니면 대학 신입생에게 꼭 권장해 주고싶다. 난 너무 늦었다. 그 오랜 방황이 한탄 스러울 뿐이다. 이제 시작이다.  자신을 찾아가는 길..
#             </div>
# </div>
# <div class="reviewInfoLike">
# <span class="txt_sympathy">2명이 이 리뷰를 추천합니다.</span>
# <a class="btnC s_size " href="javascript:void(0);" onclick="RecommendReviewForProduct(129392,1169361,64,'ALL',0,1,176787,0,'infoset_reviewContentList', this);"><span class="bWrap"><em class="bgGD ico_sympathy">공감</em><em class="yes_b txt">2</em></span></a>
# <a class="btnC s_size" href="http://blog.yes24.com/document/129392" target="_blank"><span class="bWrap"><em class="txt">댓글 <strong class="yes_b">0</strong></em><em class="bgYUI ico_goS"></em></span></a>
# <a class="downSize" href="javascript:void(0);" onclick="toggleInfoSubSet(this);">접어보기<em class="bgYUI ico_arr"></em></a>
# </div>
# </div>
# <!-- ############################## 리뷰 하나 반복 끝 ############################## -->
# <div class="review_sort sortBot">
# <div class="review_sortLft"><div class="yesUI_pagenS"><a class="bgYUI first" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=1&amp;Type=ALL" onclick="urlClickForReview(this);return false;">처음</a>
# <a class="bgYUI prev" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=60&amp;Type=ALL" onclick="urlClickForReview(this);return false;">이전</a>
# <a class="num" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=61&amp;Type=ALL" onclick="urlClickForReview(this);return false;">61</a>
# <a class="num" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=62&amp;Type=ALL" onclick="urlClickForReview(this);return false;">62</a>
# <a class="num" href="/Product/communityModules/GoodsReviewList/176787?Sort=1&amp;PageNumber=63&amp;Type=ALL" onclick="urlClickForReview(this);return false;">63</a>
# <strong class="num">64</strong>
# <a class="bgYUI next dim" href="javascript:void(0);">다음</a>
# <a class="bgYUI end dim" href="javascript:void(0);">끝</a></div></div></div>
# <script>function urlClickForReview(obj) {    var url = $(obj).attr('href');    var current_sorting_id = $(obj).attr('id');    var gdreviewTab = new Object();    var sort_tp = getSortTp(current_sorting_id);    if (typeof (current_sorting_id) != 'undefined') {        setCookie('LAST_REVIEW_TAB', sort_tp, 30);    }    if ($('#infoset_reviewTab').hasClass('yesTab_nor')) {        gdreviewTab = $('#infoset_reviewTab');    } else {        gdreviewTab = $('#score_reivew_result');    }    $('html, body').stop().animate({ scrollTop: gdreviewTab.offset().top - 101 }, 300, 'easeInOutQuart');    loadingShow('infoset_reviewContentList');    loadItem('infoset_reviewContentList', url);}</script>
# <div class="review_sortRgt" id="review_sort_areaB">
# <label><input id="chkOrderReviewForReviewB" onchange="wiseLog('Pcode','012_004_002');fnDojungAfterBuyForReview(this,1);" type="checkbox"/> 구매리뷰</label>
# <a class="on" href="/Product/communityModules/GoodsReviewList/176787?Type=ALL&amp;Sort=1&amp;PageNumber=1" id="review_recent" onclick="wiseLog('Pcode','012_004_003');urlClickForReview(this);return false;">최근순</a>
# <em class="divi">|</em>
# <a class="" href="/Product/communityModules/GoodsReviewList/176787?Type=ALL&amp;Sort=2&amp;PageNumber=1" id="review_recommend" onclick="wiseLog('Pcode','012_004_004');urlClickForReview(this);return false;">추천순</a>
# <em class="divi">|</em>
# <a class="" href="/Product/communityModules/GoodsReviewList/176787?Type=ALL&amp;Sort=3&amp;PageNumber=1" id="review_star_score" onclick="wiseLog('Pcode','012_004_005');urlClickForReview(this);return false;">별점순</a>
# </div>
#
# <script type="text/javascript">
#         var dojungAfterBuy = "0";
#         var review_pagerShowYn = "";
#
#         if (dojungAfterBuy == 0) {
#             $("#chkOrderReviewForReview").attr("checked",false)
#             $("#chkOrderReviewForReviewB").attr("checked",false)
#         } else {
#             $("#chkOrderReviewForReview").attr("checked",true)
#             $("#chkOrderReviewForReviewB").attr("checked",true)
#         }
#
#         //데이터가 없는 경우, pager hidden 처리
#         $("#infoset_reivew .yesUI_pagenS a.bgYUI").css("display", review_pagerShowYn);
#
#         //리뷰탭 리뷰수 재조회
#         var reviewCountText = '320';
#         var photoReviewCountText = '10';
#         var starReviewCountText = '20';
#
#         $("#emReviewCountText").text("(" + reviewCountText + ")");
#         $("#emPhotoReviewCountText").text("("+photoReviewCountText+")");
#         $("#emStarReviewCountText").text("(" + starReviewCountText + ")");
#
#         //eBook (관리분류 004) 이면서 19금 도서인 경우 리뷰 원문 주소 삭제
#         $(document).ready(function () {
#             if (g_GoodsSortNo.indexOf("004") == 0 && g_GoodsLimitAge == "Y") {
#                 $(".review_lnk").remove();
#                 $("#infoset_reviewContentList a[onclick*=makeBlogMnu]").each(function () {
#                     var $this = $(this);
#                     $this.contents().unwrap().wrap('<span class="' + $this.attr("class") + '"></span>');
#                 });
#             }
#         });
#     </script>

# %%
rall
